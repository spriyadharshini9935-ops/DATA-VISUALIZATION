# %% [markdown]
# <a href="https://colab.research.google.com/github/spriyadharshini9935-ops/DATA-VISUALIZATION/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
